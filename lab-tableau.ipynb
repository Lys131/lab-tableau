# %% [markdown]
# ## Extracting data from csv file

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/we_fn_use_c_marketing_customer_value_analysis.csv"

# %%
df_tableau = pd.read_csv(url)

# %%
df_tableau.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %% [markdown]
# ## Saving dataframe to Excel file

# %%
df_tableau.to_excel("data_tableau.xlsx")

# %% [markdown]
# ## Visualizations from Tableau

# %% [markdown]
# ### Gender distribution

# %%
from IPython.display import Image, display

display(Image(filename='Gender_dist.png'))

# %% [markdown]
# ### Employment and gender distribution

# %%
display(Image(filename='Employment_gender_dist.png'))

# %% [markdown]
# ### State distribution

# %%
display(Image(filename='State_dist.png'))

# %% [markdown]
# ### Marital status and gender crosstable

# %%
display(Image(filename='Marital_gender_crosstable.png'))

# %% [markdown]
# ## Dashboard

# %%
display(Image(filename='Customers_demographics.png'))

# %% [markdown]
# ## Saving the work

# %%
import os

file_path = '/Users/laurasuemitsu/Desktop/DATA_FT_May_2025/Labs/Week 6/lab-tableau/tableau-lab.twbx'

if os.path.exists(file_path):
    with open(file_path, 'rb') as file:
        content = file.read()
        print("File size:", len(content), "bytes")
else:
    print("File does not exist in the specified path.")
# Out:
# File size: 360562 bytes
